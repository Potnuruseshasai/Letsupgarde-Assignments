# %%
print("Hello World")
# Out:
# Hello World

# %%
print('Hello \
Python')
# Out:
# Hello Python

# %%
print("""██─▄███▄███▄─██▄──▄██──▄███▄──██──██
██─█████████──▀████▀──██▀─▀██─██──██
██──▀█████▀─────██────██▄─▄██─██──██
██────▀█▀───────██─────▀███▀──▀████▀ """)
# Out:
# ██─▄███▄███▄─██▄──▄██──▄███▄──██──██
# ██─█████████──▀████▀──██▀─▀██─██──██
# ██──▀█████▀─────██────██▄─▄██─██──██
# ██────▀█▀───────██─────▀███▀──▀████▀

# %%
print("Python's World")
# Out:
# Python's World

# %%
print("Hello \nLetsupgrade")
# Out:
# Hello
# Letsupgrade

# %%
print('Pyhton\'s World')
# Out:
# Pyhton's World

# %%
name="Sesha"
marks=99.999
age=21
print("My name is",name,"I got",marks,"marks and my age is",age)
# Out:
# My name is Sesha I got 99.999 marks and my age is 21

# %%
print("My name is %s I got %f marks and my age is %d"%(name,marks,age))
# Out:
# My name is Sesha I got 99.999000 marks and my age is 21

# %%
print("My name is %10s I got %10.3f marks and my age is %d"%(name,marks,age))
# Out:
# My name is      Sesha I got     99.999 marks and my age is 21

# %%
name='Sesha'
marks=99.99
age=21
print(f"My name is {name} I got {marks} marks and my age is {age}")
# Out:
# My name is Sesha I got 99.99 marks and my age is 21

# %%
_10=20

# %%
x=y=10

# %%
x
# Out:
# 10

# %%
y
# Out:
# 10

# %%
x=20

# %% [markdown]
# Ram address

# %%
id(x)
# Out:
# 94619770533088

# %%
y=20

# %%
id(y)
# Out:
# 94619770533088

# %% [markdown]
# Operators

# %%
5**5
# Out:
# 3125

# %%
10+20
# Out:
# 30

# %%
20-10
# Out:
# 10

# %%
10/2
# Out:
# 5.0

# %%
10/3
# Out:
# 3.3333333333333335

# %%
10%3
# Out:
# 1

# %%
10//3
# Out:
# 3

# %%
a=10
b=20
a==b
# Out:
# False

# %%
c=10
a==c
# Out:
# True

# %%
c<=a
# Out:
# True

# %%
a>=b
# Out:
# False

# %%
a!=b
# Out:
# True

# %%
a=240
b=1
a|b
# Out:
# 241

# %%
bin(b)
# Out:
# '0b1'

# %%
bin(a)
# Out:
# '0b11110000'

# %%
a&b
# Out:
# 0

# %%
a=1
b=20
a>20 or 10>9
# Out:
# True

# %%
a>20 and 10>9
# Out:
# False

# %%
10>9 and 20>m
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-8-9fa2eda33963> in <module>
# ----> 1 10>9 and 20>m
#
# NameError: name 'm' is not defined

# %%
10<9 and 20>m
# Out:
# False

# %%
not 10<9
# Out:
# True

# %%
strl="pythonprogramming"
'a' in strl
# Out:
# True

# %%
'x' not in strl
# Out:
# True

# %%
a=10
b=10
a==b
# Out:
# True

# %%
a is b
# Out:
# True

# %%
x=1.5
y=1.5
x==y
# Out:
# True

# %%
x is y
# Out:
# False

# %%
a=257
b=257
a==b
# Out:
# True

# %%
a is b
# Out:
# False

# %%
2**-1
# Out:
# 0.5
